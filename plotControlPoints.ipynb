# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read in the data
df = pd.read_csv('boxcpsBsplines02.csv')

# Print the first few rows of the dataframe
print(df.head())

# Plot the data
x = df['x']
y = df['y']
z = df['z']
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_aspect('equal')
plt.show()
# Out:
#           x         y         z
# 0 -0.099785 -0.425087  0.636350
# 1 -0.016181 -0.425087  0.706501
# 2  0.067422 -0.425087  0.776653
# 3  0.151026 -0.425087  0.846804
# 4  0.234629 -0.425087  0.916956

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from stl import mesh

# Load the STL file
your_mesh = mesh.Mesh.from_file('constant/triSurface/DTC-scaled.stl')

# Create a new plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Load the vectors
vectors = your_mesh.vectors

# Plot the vectors
for vector in vectors:
    v0 = vector[0]
    v1 = vector[1]
    v2 = vector[2]
    v = np.array([v0, v1, v2, v0])  # Create a closed polygon for each face
    ax.plot(v[:, 0], v[:, 1], v[:, 2], color='b')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
import numpy as np
from stl import mesh
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

# Step 1: Load the STL file
your_mesh = mesh.Mesh.from_file('constant/triSurface/DTC-scaled.stl')

# Step 2: Create a plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Step 3: Get the vertices and faces
vertices = np.array(your_mesh.vectors)
faces = np.array(your_mesh.v0, your_mesh.v1, your_mesh.v2)

# Step 4: Plot the vertices and faces
ax.add_collection3d(mplot3d.art3d.Poly3DCollection(vertices))

# Auto scale to the mesh size
scale = your_mesh.points.flatten()
ax.auto_scale_xyz(scale, scale, scale)

# Show the plot
plt.show()

# %%
from stl import mesh
from mpl_toolkits import mplot3d
from matplotlib import pyplot

# Create a new plot
figure = pyplot.figure()
axes = mplot3d.Axes3D(figure)

# Load the STL files and add the vectors to the plot
your_mesh = mesh.Mesh.from_file('constant/triSurface/DTC-scaled.stl')
axes.add_collection3d(mplot3d.art3d.Poly3DCollection(your_mesh.vectors))

# # Auto scale to the mesh size
# scale = your_mesh.points.flatten(-1)
# axes.auto_scale_xyz(scale, scale, scale)

# Show the plot to the screen
pyplot.show()
